# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
R_534_4=pd.read_csv("Resultados_534_4.out", sep="\t")
R_534_4.columns = R_534_4.columns.str.replace(' ','')
for i in range(1,11):
    plt.plot(R_534_4[f'Node{i}'])

# %%
R_534_3=pd.read_csv("Resultados_534_3.out", sep="\t")
R_534_3.columns = R_534_3.columns.str.replace(' ','')
for i in range(1,11):
    plt.plot(R_534_3[f'Node{i}'])

# %%
R_534_2=pd.read_csv("Resultados_534_2.out", sep="\t")
R_534_2.columns = R_534_2.columns.str.replace(' ','')
for i in range(1,11):
    plt.plot(R_534_2[f'Node{i}'])

# %%
R_534_1=pd.read_csv("Resultados_534_1.out", sep="\t")
R_534_1.columns = R_534_1.columns.str.replace(' ','')
for i in range(1,11):
    plt.plot(R_534_1[f'Node{i}'])
